# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

nume=['Id','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Type']
data =pandas.read_csv('Glass.csv',names=nume,index_col='Id')

data.plot()

# %%
data.head()
# Out:
#          RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# Id
# 1   1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 2   1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 3   1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 4   1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 5   1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
data.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516523   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
data.plot.bar(stacked=True,figsize=(10,10))

# %%
data['RI'].plot.area()
"""se poate obserava cum indiferente de reflexie ramane in intevalul (1.4,1,6)"""
# Out:
# 'se poate obserava cum indiferente de reflexie ramane in intevalul (1.4,1,6)'

# %%
#data[['Type','Fe']].plot.area()
data['Fe'].plot.area()
"cantitatea de fier se afla in 0.0 su 0.5"
# Out:
# 'cantitatea de fier se afla in 0.0 su 0.5'

# %%
data[['Fe','Type']].plot.bar(stacked=True,figsize=(10,10))
"""din acest tabel se poate observa cum fierul este mai degraba un rezid decat 
un factor important in determinarea tipului de sticala """
# Out:
# 'din acest tabel se poate observa cum fierul este mai degraba un rezid decat \nun factor important in determinarea tipului de sticala '

# %%
data.plot(subplots=True,figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002D69B87ABA8>,
# ...
#       dtype=object)

# %%
data['Ba'].plot.area()
"""din acest tabel rezulta ca bariul este un elemetn deteminat pentru sticla de tip 7"""
# Out:
# 'din acest tabel rezulta ca bariul este un elemetn deteminat pentru sticla de tip 7'

# %%
data[['Ba','Type']].plot.bar(figsize=(10,10))

# %%
data[['Al','Type']].plot.area()
"""se poate observa cum Alu este prezent in cantitai mai mari in sticla de tip 7 """
# Out:
# 'se poate observa cum Alu este prezent in cantitai mai mari in sticla de tip 7 '

# %%
data[['Al','Type']].plot.bar(figsize=(20,5))

# %%
data[['Mg','Type']].plot.area()

# %%
data[['Mg','Type']].plot.bar(figsize=(20,5))
"""sticla de tip 7 si 5 contine cantitai scazute de magneziu """
# Out:
# 'sticla de tip 7 si 5 contine cantitai scazute de magneziu '

# %%
serie=pandas.Series(data.loc[1])

serie.plot.pie(figsize=(10,10),autopct='%.2f')

# %%
'''se observa procentul cantitatii un anumit element chimic continut'''
serie=pandas.Series(data.loc[90])

serie.plot.pie(figsize=(10,10),autopct='%.2f')

# %%
serie=pandas.Series(data.loc[200])

serie.plot.pie(figsize=(10,10),autopct='%.2f')

# %%
plt.figure();
data.diff().hist(color='k', alpha=0.5, bins=50,figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002D69FB026A0>,
# ...
#       dtype=object)

# %%
'''used to visualize the distribution of values within each column.'''
data = pd.DataFrame(np.random.rand(20, 10), columns=['Id','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe'])
data.plot.box()

# %%
data = pd.DataFrame(np.random.rand(20, 10), columns=['Id','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe'])

data.plot.area();

# %%
data.plot.area(stacked=False)
'''putem vedea elementele care au aceeasi cantitatea si oscilatiile acestora'''
# Out:
# 'puteme vedea elementele care au aceeasi cantitatea si oscilatiile acestora'

# %%
data = pd.DataFrame(np.random.randn(1000, 2), columns=['Fe', 'K'])
data['K'] = data['K'] + np.arange(1000)
data.plot.hexbin(x='Fe', y='K', gridsize=25)
'''se observa combinatia de fe cu k'''

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002D6A11EA9E8>,
# ...
#       dtype=object)
