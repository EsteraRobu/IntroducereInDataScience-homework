# %%
import pandas as pd
import numpy as np

from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.neighbors import KNeighborsRegressor,KNeighborsClassifier
from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier
from sklearn.linear_model import LinearRegression


from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV , RandomizedSearchCV,train_test_split

from sklearn.model_selection import cross_validate,cross_val_score

from sklearn.datasets import load_files

from sklearn.feature_extraction.text import CountVectorizer

from sklearn.metrics import f1_score
from sklearn.metrics import make_scorer
import json

from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.decomposition  import TruncatedSVD

import re
import nltk

from nltk.stem import WordNetLemmatizer

# %% [markdown]
# # KNeighborsClassifire

# %%
"cu asta nu merge"
def kNeighbors(X,Y):
    model=KNeighborsClassifier()
    paramz ={'n_neighbors':[2,4],'algorithm':('ball_tree','kd_tree')}
    grid_search = GridSearchCV(estimator = model, param_grid=paramz, scoring=('accuracy')
                               , cv=3, return_train_score=True, iid=False)
    GS_result=cross_validate(grid_search,X,Y,
                                cv=5,scoring=('accuracy'
                                              ,'f1_macro'),return_train_score=True)
    random_search=RandomizedSearchCV(estimator=model,param_distributions=paramz ,scoring=('accuracy')
                                ,cv=3,return_train_score=True,iid=False)
    RS_result = cross_validate(random_search, X, Y, cv=5, scoring=('accuracy','f1_macro'), return_train_score=True)
    return GS_result, RS_result

# %% [markdown]
# # DecisionTree

# %%
def dTree(X,Y):
    model=DecisionTreeClassifier()
    paramz ={'criterion':('gini','entropy')}
    grid_search = GridSearchCV(estimator = model, param_grid=paramz, scoring=('accuracy')
                               , cv=3, return_train_score=True, iid=False)
    GS_result=cross_validate(grid_search,X,Y,
                                cv=5,scoring=('accuracy'
                                              ,'f1_macro'),return_train_score=True)
    random_search=RandomizedSearchCV(estimator=model,param_distributions=paramz ,scoring=('accuracy')
                                ,cv=3,return_train_score=True,iid=False)
    RS_result = cross_validate(random_search, X, Y, cv=5, scoring=('accuracy','f1_macro'), return_train_score=True)
    return GS_result, RS_result

# %% [markdown]
# # Support Vector Clasification

# %%
def svc(X,Y):
    model=SVC()
    paramz ={'C':[3,7],'kernel':('linear', 'poly', 'rbf' )}
    grid_search = GridSearchCV(estimator = model, param_grid=paramz, scoring=('accuracy')
                               , cv=3, return_train_score=True, iid=False)
    GS_result=cross_validate(grid_search,X,Y,
                                cv=5,scoring=('accuracy'
                                              ,'f1_macro'),return_train_score=True)
    random_search=RandomizedSearchCV(estimator=model,param_distributions=paramz ,scoring=('accuracy')
                                ,cv=3,return_train_score=True,iid=False)
    RS_result = cross_validate(random_search, X, Y, cv=5, scoring=('accuracy','f1_macro'), return_train_score=True)
    
    return GS_result, RS_result

# %% [markdown]
# # Random Forest Classifire

# %%
def rTree(X,Y):
    model=RandomForestClassifier()
    paramz ={'n_estimators':[20,30,40],'criterion':('gini','entropy')}
    grid_search = GridSearchCV(estimator = model, param_grid=paramz, scoring=('accuracy')
                               , cv=3, return_train_score=True, iid=False)
    GS_result=cross_validate(grid_search,X,Y,
                                cv=5,scoring=('accuracy'
                                              ,'f1_macro'),return_train_score=True)
    random_search=RandomizedSearchCV(estimator=model,param_distributions=paramz ,scoring=('accuracy')
                                ,cv=3,return_train_score=True,iid=False)
    RS_result = cross_validate(random_search, X, Y, cv=5, scoring=('accuracy','f1_macro'), return_train_score=True)
    
    return GS_result, RS_result

# %% [markdown]
# # SMS

# %% [markdown]
# - Continut :
# mesaje etichetate cu spam sau ham
# - Format:
# eticheta \t mesaj
# - Se urmareste analiza continutului  unui mesaj pentru a deduce daca acesta este de tip spam sau ham

# %%
o= pd.read_csv('sms.txt',header=None,sep='\t')
x=o[1]
y=o[0]
data_set=x.values
# Out:
#            0                       1
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30

# %%
documents = []

stemmer = WordNetLemmatizer()

for sen in range(0, len(data_set)):  
    # Remove all the special characters
    document = re.sub(r'\W', ' ', str(data_set[sen]))

    # remove all single characters
    document = re.sub(r'\s+[a-zA-Z]\s+', ' ', document)

    # Remove single characters from the start
    document = re.sub(r'\^[a-zA-Z]\s+', ' ', document) 

    # Substituting multiple spaces with single space
    document = re.sub(r'\s+', ' ', document, flags=re.I)

    # Removing prefixed 'b'
    document = re.sub(r'^b\s+', '', document)

    # Converting to Lowercase
    document = document.lower()

    # Lemmatization
    document = document.split()

    document = [stemmer.lemmatize(word) for word in document]
    document = ' '.join(document)

    documents.append(document)

# %%
vect= CountVectorizer(stop_words='english')
bow_sms=vect.fit_transform(documents)
sum_words = bow_sms.sum(axis=0) 
words_freq = [(word, sum_words[0, idx]) for word, idx in vect.vocabulary_.items()]
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
Y=y.values

# %%
import matplotlib.pyplot as plt

df1 = pd.DataFrame(words_freq[:15], columns = ['Messages' , 'count'])
ax=df1.groupby('Messages').sum()['count'].sort_values(ascending=False).plot(
    kind='bar', title='Top 15 cuvinte in review inainte de eliminarea stop words')
ax.set_ylabel("Aparitii")
ax.set_xlabel("Cuvant in reviews")
plt.show()

# %%
aux1,aux2=rTree(bow_sms,Y)
data=pd.DataFrame()
aux_data1=pd.DataFrame(aux1)
aux_data2=pd.DataFrame(aux2)
data=data.append(aux_data1,ignore_index=True)
data=data.append(aux_data2,ignore_index=True)
data
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
#     fit_time  score_time  test_accuracy  train_accuracy  test_f1_macro  \
# 0  26.653513    0.032447       0.984753        0.999327       0.965599
# 1  28.166334    0.069071       0.974888        1.000000       0.942111
# 2  28.343916    0.070284       0.971275        0.999776       0.931695
# 3  25.159956    0.030299       0.968582        0.999327       0.925533
# 4  28.533190    0.078156       0.973070        1.000000       0.937184
# 5  29.158043    0.058455       0.984753        1.000000       0.965805
# 6  27.278458    0.048423       0.977578        1.000000       0.949410
# 7  26.277097    0.031281       0.973968        0.999327       0.938695
# 8  26.739922    0.062485       0.968582        1.000000       0.926011
# 9  27.493495    0.048420       0.970377        1.000000       0.930239
#
#    train_f1_macro
# 0        0.998546
# 1        1.000000
# 2        0.999517
# 3        0.998548
# 4        1.000000
# 5        1.000000
# 6        1.000000
# 7        0.998548
# 8        1.000000
# 9        1.000000

# %%
aux1,aux2=kNeighbors(bow_sms,Y)
data=data.iloc[0:0]
aux_data1=aux_data1.iloc[0:0]
aux_data2=aux_data2.iloc[0:0]
aux_data1=pd.DataFrame(aux1)
aux_data2=pd.DataFrame(aux2)
data=data.append(aux_data1,ignore_index=True)
data=data.append(aux_data2,ignore_index=True)
data
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
#    fit_time  score_time  test_accuracy  train_accuracy  test_f1_macro  \
# 0  7.903913    0.455278       0.950673        0.999776       0.875676
# 1  6.935870    0.378550       0.947982        1.000000       0.865578
# 2  7.592487    0.413449       0.945242        1.000000       0.855989
# 3  7.499220    0.414080       0.949731        1.000000       0.871133
# 4  7.562295    0.445021       0.945242        1.000000       0.855989
# 5  7.319706    0.379216       0.950673        0.999776       0.875676
# 6  7.136355    0.397290       0.947982        1.000000       0.865578
# 7  7.305140    0.407402       0.945242        1.000000       0.855989
# 8  7.301101    0.397814       0.949731        1.000000       0.871133
# 9  7.636832    0.382842       0.945242        1.000000       0.855989
#
#    train_f1_macro
# 0        0.999517
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
# 5        0.999517
# 6        1.000000
# 7        1.000000
# 8        1.000000
# 9        1.000000

# %%
aux1,aux2=dTree(bow_sms,Y)
data=data.iloc[0:0]
aux_data1=aux_data1.iloc[0:0]
aux_data2=aux_data2.iloc[0:0]
aux_data1=pd.DataFrame(aux1)
aux_data2=pd.DataFrame(aux2)
data=data.append(aux_data1,ignore_index=True)
data=data.append(aux_data2,ignore_index=True)
data
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
#    fit_time  score_time  test_accuracy  train_accuracy  test_f1_macro  \
# 0  1.349762    0.000000       0.973991             1.0       0.942694
# 1  1.360719    0.007471       0.974888             1.0       0.945464
# 2  1.327735    0.014525       0.977558             1.0       0.948467
# 3  1.314205    0.001996       0.966786             1.0       0.925566
# 4  1.349711    0.000000       0.963196             1.0       0.917519
# 5  1.385135    0.000000       0.975785             1.0       0.946955
# 6  1.416383    0.000000       0.973991             1.0       0.943354
# 7  1.298993    0.016752       0.974865             1.0       0.942461
# 8  1.317946    0.000000       0.964991             1.0       0.922469
# 9  1.367613    0.000000       0.964991             1.0       0.922009
#
#    train_f1_macro
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# 5             1.0
# 6             1.0
# 7             1.0
# 8             1.0
# 9             1.0

# %%
aux1,aux2=svc(bow_sms,Y)
data=data.iloc[0:0]
aux_data1=aux_data1.iloc[0:0]
aux_data2=aux_data2.iloc[0:0]
aux_data1=pd.DataFrame(aux1)
aux_data2=pd.DataFrame(aux2)
data=data.append(aux_data1,ignore_index=True)
data=data.append(aux_data2,ignore_index=True)
data
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
#     fit_time  score_time  test_accuracy  train_accuracy  test_f1_macro  \
# 0  18.561284    0.245709       0.981166             1.0       0.957759
# 1  17.909465    0.225981       0.985650             1.0       0.967720
# 2  18.008884    0.207403       0.980251             1.0       0.954510
# 3  18.372512    0.218449       0.982047             1.0       0.959152
# 4  18.489286    0.234301       0.983842             1.0       0.963237
# 5  18.142816    0.233366       0.981166             1.0       0.957759
# 6  17.857422    0.218158       0.985650             1.0       0.967720
# 7  17.974933    0.218616       0.980251             1.0       0.954510
# 8  18.204948    0.215245       0.982047             1.0       0.959152
# 9  18.149933    0.252726       0.983842             1.0       0.963237
#
#    train_f1_macro
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# 5             1.0
# 6             1.0
# 7             1.0
# 8             1.0
# 9             1.0

# %% [markdown]
# # Amazon review

# %% [markdown]
# - Descriere/Continut:
# Contine fraze etichetate pozitiv=1 sau negativ=0, extrase din recenziile produselor de pe site-ul amazon.com.
#
# - Format:
# propozitie \t scor
#
# - Se urmareste analizarea opiniei pentru a determina daca este una negativa sau pozitiva in legatura cu produsul respectiv;

# %%
yoyo=pd.read_csv('Amazon.txt',header=None,sep='\t')

# %%
yoyo.describe()
# Out:
#                 1
# count  1000.00000
# mean      0.50000
# std       0.50025
# min       0.00000
# 25%       0.00000
# 50%       0.50000
# 75%       1.00000
# max       1.00000

# %%
yoyo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
# 0    1000 non-null object
# 1    1000 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 15.7+ KB

# %%
x2=yoyo[0]
y2=yoyo[1]
data_set2=x2.values
documents2 = []

stemmer = WordNetLemmatizer()

for sen in range(0, len(data_set2)):  
    # Remove all the special characters
    document2 = re.sub(r'\W', ' ', str(data_set2[sen]))

    # remove all single characters
    document2 = re.sub(r'\s+[a-zA-Z]\s+', ' ', document2)

    # Remove single characters from the start
    document2 = re.sub(r'\^[a-zA-Z]\s+', ' ', document2) 

    # Substituting multiple spaces with single space
    document2 = re.sub(r'\s+', ' ', document2, flags=re.I)

    # Removing prefixed 'b'
    document2 = re.sub(r'^b\s+', '', document2)

    # Converting to Lowercase
    document2 = document2.lower()

    # Lemmatization
    document2 = document2.split()

    document2 = [stemmer.lemmatize(word) for word in document2]
    document2 = ' '.join(document2)

    documents2.append(document2)
    
vect2= CountVectorizer(stop_words='english')
bow_amazon=vect2.fit_transform(documents2)
Y2=y2.values

# %%
sum_words = bow_amazon.sum(axis=0) 
words_freq = [(word, sum_words[0, idx]) for word, idx in vect2.vocabulary_.items()]
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)

# %%
df2 = pd.DataFrame(words_freq[:15], columns = ['Word' , 'count'])
ax=df2.groupby('Word').sum()['count'].sort_values(ascending=False).plot(
    kind='bar', title='Top 15 cuvinte in review inainte de eliminarea stop words')
ax.set_ylabel("Aparitii")
ax.set_xlabel("Cuvant in reviews")
plt.show()

# %%
aux1,aux2=kNeighbors(bow_author,Y2)
data=pd.DataFrame()
aux_data1=aux_data1.iloc[0:0]
aux_data2=aux_data2.iloc[0:0]
aux_data1=pd.DataFrame(aux1)
aux_data2=pd.DataFrame(aux2)
data=data.append(aux_data1,ignore_index=True)
data=data.append(aux_data2,ignore_index=True)
data
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:217: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
#    fit_time  score_time  test_accuracy  train_accuracy  test_f1_macro  \
# 0  0.353914    0.031241          0.760         0.90625       0.758040
# 1  0.354376    0.015623          0.675         0.91750       0.674341
# 2  0.417404    0.026098          0.665         0.84125       0.659683
# 3  0.342864    0.015619          0.665         0.83500       0.664790
# 4  0.344872    0.022144          0.690         0.91000       0.687468
# 5  0.329090    0.015628          0.760         0.90625       0.758040
# 6  0.403651    0.019248          0.675         0.91750       0.674341
# 7  0.341471    0.015631          0.665         0.84125       0.659683
# 8  0.331477    0.015624          0.665         0.83500       0.664790
# 9  0.331437    0.015624          0.690         0.91000       0.687468
#
#    train_f1_macro
# 0        0.905419
# 1        0.916935
# 2        0.841230
# 3        0.834875
# 4        0.909265
# 5        0.905419
# 6        0.916935
# 7        0.841230
# 8        0.834875
# 9        0.909265

# %%
aux1,aux2=svc(bow_author,Y2)
data=data.iloc[0:0]
aux_data1=aux_data1.iloc[0:0]
aux_data2=aux_data2.iloc[0:0]
aux_data1=pd.DataFrame(aux1)
aux_data2=pd.DataFrame(aux2)
data=data.append(aux_data1,ignore_index=True)
data=data.append(aux_data2,ignore_index=True)
data
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
#    fit_time  score_time  test_accuracy  train_accuracy  test_f1_macro  \
# 0  2.293977    0.031277          0.840             1.0       0.839936
# 1  1.980926    0.031275          0.830             1.0       0.829932
# 2  1.904961    0.031240          0.810             1.0       0.809829
# 3  1.903934    0.037760          0.795             1.0       0.794954
# 4  1.920653    0.022169          0.810             1.0       0.809924
# 5  1.960725    0.020195          0.840             1.0       0.839936
# 6  1.942370    0.030210          0.830             1.0       0.829932
# 7  1.889656    0.037785          0.810             1.0       0.809829
# 8  1.896724    0.031244          0.795             1.0       0.794954
# 9  1.913807    0.020196          0.810             1.0       0.809924
#
#    train_f1_macro
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# 5             1.0
# 6             1.0
# 7             1.0
# 8             1.0
# 9             1.0

# %%
aux1,aux2=dTree(bow_author,Y2)
data=data.iloc[0:0]
aux_data1=aux_data1.iloc[0:0]
aux_data2=aux_data2.iloc[0:0]
aux_data1=pd.DataFrame(aux1)
aux_data2=pd.DataFrame(aux2)
data=data.append(aux_data1,ignore_index=True)
data=data.append(aux_data2,ignore_index=True)
data
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
#    fit_time  score_time  test_accuracy  train_accuracy  test_f1_macro  \
# 0  0.231777         0.0          0.785             1.0       0.784866
# 1  0.216211         0.0          0.800             1.0       0.799499
# 2  0.184909         0.0          0.710             1.0       0.709971
# 3  0.184922         0.0          0.715             1.0       0.714135
# 4  0.184888         0.0          0.720             1.0       0.715187
# 5  0.193972         0.0          0.800             1.0       0.800000
# 6  0.200239         0.0          0.800             1.0       0.799499
# 7  0.178420         0.0          0.760             1.0       0.759133
# 8  0.200370         0.0          0.740             1.0       0.739583
# 9  0.184834         0.0          0.730             1.0       0.728261
#
#    train_f1_macro
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# 5             1.0
# 6             1.0
# 7             1.0
# 8             1.0
# 9             1.0

# %%
aux1,aux2=rTree(bow_author,Y2)
data=data.iloc[0:0]
aux_data1=aux_data1.iloc[0:0]
aux_data2=aux_data2.iloc[0:0]
aux_data1=pd.DataFrame(aux1)
aux_data2=pd.DataFrame(aux2)
data=data.append(aux_data1,ignore_index=True)
data=data.append(aux_data2,ignore_index=True)
data
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
#    fit_time  score_time  test_accuracy  train_accuracy  test_f1_macro  \
# 0  3.158169    0.010118          0.825         1.00000       0.824645
# 1  2.766863    0.010038          0.795         1.00000       0.794995
# 2  2.755373    0.018149          0.750         1.00000       0.749775
# 3  2.776179    0.010104          0.785         0.99875       0.783435
# 4  2.758128    0.010101          0.770         1.00000       0.769793
# 5  2.831203    0.018153          0.805         0.99875       0.804761
# 6  2.706672    0.008065          0.805         0.99875       0.804878
# 7  2.774379    0.018144          0.815         1.00000       0.814625
# 8  2.850776    0.000000          0.775         1.00000       0.774543
# 9  2.859178    0.020228          0.780         0.99875       0.778203
#
#    train_f1_macro
# 0         1.00000
# 1         1.00000
# 2         1.00000
# 3         0.99875
# 4         1.00000
# 5         0.99875
# 6         0.99875
# 7         1.00000
# 8         1.00000
# 9         0.99875

# %% [markdown]
# # Dataset description

# %% [markdown]
# # Laborator 10
# 1. [Clasificare de SMS-uri](https://archive.ics.uci.edu/ml/datasets/SMS+Spam+Collection)
# Colecția SMS Spam este un set de mesaje etichetate prin SMS care au fost colectate pentru cercetarea SMS Spam.
# Acesta conține
# un set de mesaje SMS în limba engleză de 5.574 de mesaje, etichetate conform căruia sunt ham (legitim) sau spam.
# mesajele nu sunt sortate cronologic
# mesajele ham sunt legitime sau spam
# pe prima coloana vom avea cuvantul spam sau ham care indica daca mesajul este legitim sau nu.
#
# 1. [Amazon Commerce reviews set Data Set](https://archive.ics.uci.edu/ml/datasets/Amazon+Commerce+reviews+set)
# Setul de date este derivat din recenziile clienților din site-ul Amazon Commerce pentru identificarea autorilor. Majoritatea studiilor anterioare au efectuat experimente de identificare pentru doi sau zece autori.  Dar în contextul online, recenziile care trebuie identificate au, de obicei, mai mulți autori potențiali și, în mod normal
#  au fost  identificati 50 dintre cei mai activi utilizatori (reprezentați de un ID unic și un nume de utilizator unic) care au postat frecvent recenzii în aceste grupuri de știri. Numărul de recenzii pe care le-am colectat pentru fiecare autor este de 30.
